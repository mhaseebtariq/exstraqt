# %%
import os
import sys
import time
from datetime import timedelta

import nbformat
import numpy as np
from nbconvert.preprocessors import ExecutePreprocessor

# %%
if (
    sys.version_info.major,
    sys.version_info.minor,
    sys.version_info.micro,
) != (3, 9, 19):
    raise EnvironmentError("Only runs efficiently, as tested, on Python 3.9.19")

# %%
### TO HIDE THE LOGGING FROM SPARK ###

from IPython.display import HTML

HTML('''<script>
var code_show_err = false;
var code_toggle_err = function() {
    var stderrNodes = document.querySelectorAll('[data-mime-type="application/vnd.jupyter.stderr"]')
    var stderr = Array.from(stderrNodes)
    if (code_show_err){
        stderr.forEach(ele => ele.style.display = 'block');
    } else {
        stderr.forEach(ele => ele.style.display = 'none');
    }
    code_show_err = !code_show_err
}
document.addEventListener('DOMContentLoaded', code_toggle_err);
</script>
To toggle on/off output_stderr, click <a onclick="javascript:code_toggle_err()">here</a>.''')
# Out:
# <script>
# var code_show_err = false;
# var code_toggle_err = function() {
#     var stderrNodes = document.querySelectorAll('[data-mime-type="application/vnd.jupyter.stderr"]')
#     var stderr = Array.from(stderrNodes)
#     if (code_show_err){
#         stderr.forEach(ele => ele.style.display = 'block');
#     } else {
#         stderr.forEach(ele => ele.style.display = 'none');
#     }
#     code_show_err = !code_show_err
# }
# document.addEventListener('DOMContentLoaded', code_toggle_err);
# </script>
# To toggle on/off output_stderr, click <a onclick="javascript:code_toggle_err()">here</a>.

# %%
filename = "1_prepare_input_small.ipynb"
with open(filename) as ff:
    nb_in = nbformat.read(ff, nbformat.NO_CONVERT)

# %%
# %%time

os.environ["EXSTRAQT_HIGH_ILLICIT"] = "1"
os.environ["EXSTRAQT_FILE_SIZE"] = "Small"
executor = ExecutePreprocessor(timeout=24*60*60, kernel_name="python3")
_ = executor.preprocess(nb_in)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/07 10:19:19 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/11/07 10:19:19 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in standalone/kubernetes and LOCAL_DIRS in YARN).
# 25/11/07 10:24:07 WARN TaskSetManager: Stage 70 contains a task of very large size (1921 KiB). The maximum recommended task size is 1000 KiB.
# CPU times: user 192 ms, sys: 76.2 ms, total: 268 ms
# Wall time: 5min 7s

# %%
# %%time

os.environ["EXSTRAQT_HIGH_ILLICIT"] = "0"
os.environ["EXSTRAQT_FILE_SIZE"] = "Small"
executor = ExecutePreprocessor(timeout=24*60*60, kernel_name="python3")
_ = executor.preprocess(nb_in)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/07 10:24:27 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/11/07 10:24:27 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in standalone/kubernetes and LOCAL_DIRS in YARN).
# 25/11/07 10:30:58 WARN TaskSetManager: Stage 70 contains a task of very large size (1929 KiB). The maximum recommended task size is 1000 KiB.
# CPU times: user 200 ms, sys: 79.5 ms, total: 280 ms
# Wall time: 6min 59s

# %%
filename = "1_prepare_input_medium_or_large.ipynb"
with open(filename) as ff:
    nb_in = nbformat.read(ff, nbformat.NO_CONVERT)

# %%
# %%time

os.environ["EXSTRAQT_HIGH_ILLICIT"] = "1"
os.environ["EXSTRAQT_FILE_SIZE"] = "Medium"
executor = ExecutePreprocessor(timeout=24*60*60, kernel_name="python3")
_ = executor.preprocess(nb_in)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/07 10:31:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting Spark log level to "ERROR".
# CPU times: user 281 ms, sys: 226 ms, total: 507 ms
# Wall time: 2min 29s

# %%
# %%time

os.environ["EXSTRAQT_HIGH_ILLICIT"] = "0"
os.environ["EXSTRAQT_FILE_SIZE"] = "Medium"
executor = ExecutePreprocessor(timeout=24*60*60, kernel_name="python3")
_ = executor.preprocess(nb_in)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/07 10:33:56 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting Spark log level to "ERROR".
# CPU times: user 207 ms, sys: 82.9 ms, total: 290 ms
# Wall time: 2min 12s

# %%
# %%time

os.environ["EXSTRAQT_HIGH_ILLICIT"] = "1"
os.environ["EXSTRAQT_FILE_SIZE"] = "Large"
executor = ExecutePreprocessor(timeout=24*60*60, kernel_name="python3")
_ = executor.preprocess(nb_in)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/07 10:36:09 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting Spark log level to "ERROR".
# CPU times: user 835 ms, sys: 717 ms, total: 1.55 s
# Wall time: 14min 20s
# ----------------------------------------

# %%
# %%time

os.environ["EXSTRAQT_HIGH_ILLICIT"] = "0"
os.environ["EXSTRAQT_FILE_SIZE"] = "Large"
executor = ExecutePreprocessor(timeout=24*60*60, kernel_name="python3")
_ = executor.preprocess(nb_in)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/07 10:50:37 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting Spark log level to "ERROR".
# CPU times: user 852 ms, sys: 789 ms, total: 1.64 s
# Wall time: 14min 12s
# ----------------------------------------
